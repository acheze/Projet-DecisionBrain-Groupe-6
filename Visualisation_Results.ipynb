# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd 
from matplotlib.patches import Patch
import plotly.express as px
import pandas as pd

# %%
Result = {
1 : {'taskId':'T1','employee_name':'Ambre','start_time': 823,'Start_to_End': 60.0 , 'color':'#D65555'},
2 : {'taskId':'T2','employee_name':'Ambre','start_time': 983,'Start_to_End': 60.0, 'color': '#AD7070'},
3 : {'taskId':'T3','employee_name':'Valentin','start_time': 864,'Start_to_End': 60.0, 'color':'#F38D47'},
4 : {'taskId':'T4','employee_name':'Valentin','start_time': 720,'Start_to_End': 60.0, 'color':'#896247'},
5 : {'taskId':'T5','employee_name':'Valentin','start_time': 939,'Start_to_End': 60.0, 'color':'#CAAB2D'},
6 : {'taskId':'T6','employee_name':'Valentin','start_time': 790,'Start_to_End': 60.0, 'color':'#77A20D'},
7 : {'taskId':'T7','employee_name':'Valentin','start_time': 555,'Start_to_End': 60.0, 'color':'#A97AEC'},    
8 : {'taskId':'T8','employee_name':'Ambre','start_time': 621,'Start_to_End': 60.0, 'color':'#A41AB0'},
9 : {'taskId':'T9','employee_name':'Valentin','start_time': 480, 'Start_to_End': 75.0, 'color':'#EF1859'}, 
10 : {'taskId':'T10','employee_name':'Ambre','start_time': 496, 'Start_to_End': 60.0, 'color':'#A9CCE3'},
11 : {'taskId':'Indisponibilité', 'employee_name':'Ambre', 'start_time': 496, 'Start_to_End': 60.0, 'color':'#696969'}
         }

# %%
a = 10 #len(Tasks) = 10
df = pd.DataFrame([
    Result[i] for i in range(1,a+2)
])
print(Result)
fig, ax = plt.subplots(1, figsize =(19,10))
ax.barh(df.employee_name, df.Start_to_End, left=df.start_time, color=df.color)

##### LEGENDS #####
c_dict = {'T1':'#D65555', 'T2':'#AD7070', 'T3':'#F38D47', 'T4':'#896247', 'T5':'#CAAB2D', 'T6':'#77A20D', 'T7':'#A97AEC', 'T8':'#A41AB0', 'T9':'#EF1859', 'T10':'#A9CCE3', 'Indisponibilité': '#696969'}
legend_elements = [Patch(facecolor=c_dict[i], label=i)  for i in c_dict]
plt.legend(handles=legend_elements)

plt.show()
#ajouter les indisponibilités en gris pour dire là l'employee ne travaille pas
# Out:
# {1: {'taskId': 'T1', 'employee_name': 'Ambre', 'start_time': 823, 'Start_to_End': 60.0, 'color': '#D65555'}, 2: {'taskId': 'T2', 'employee_name': 'Ambre', 'start_time': 983, 'Start_to_End': 60.0, 'color': '#AD7070'}, 3: {'taskId': 'T3', 'employee_name': 'Valentin', 'start_time': 864, 'Start_to_End': 60.0, 'color': '#F38D47'}, 4: {'taskId': 'T4', 'employee_name': 'Valentin', 'start_time': 720, 'Start_to_End': 60.0, 'color': '#896247'}, 5: {'taskId': 'T5', 'employee_name': 'Valentin', 'start_time': 939, 'Start_to_End': 60.0, 'color': '#CAAB2D'}, 6: {'taskId': 'T6', 'employee_name': 'Valentin', 'start_time': 790, 'Start_to_End': 60.0, 'color': '#77A20D'}, 7: {'taskId': 'T7', 'employee_name': 'Valentin', 'start_time': 555, 'Start_to_End': 60.0, 'color': '#A97AEC'}, 8: {'taskId': 'T8', 'employee_name': 'Ambre', 'start_time': 621, 'Start_to_End': 60.0, 'color': '#A41AB0'}, 9: {'taskId': 'T9', 'employee_name': 'Valentin', 'start_time': 480, 'Start_to_End': 75.0, 'color': '#EF1859'}, 10: {'t
# ...
